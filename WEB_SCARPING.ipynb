# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

URL = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=ft&searchTextText=&txtKeywords=machine+learning&txtLocation=').text
soup = BeautifulSoup(URL,'html.parser')

jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs:
    #job_name = job.find('strong' , class_ = 'blkclor').text
    company_name = job.find('h3', class_ = 'joblist-comp-name').text
    Skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
    updated = job.find('span',class_ = 'sim-posted').span.text
    more_info = job.header.h2.a['href']
    
    print(f"Company Name:{company_name.strip()}")
    print(f"KeySkills: {Skills.strip()}")
    print(f"Published date: {updated.strip()}")
    print(f"More Information:{more_info}\n")
# Out:
# Company Name:Pravaig Dynamics
# KeySkills: DeepLearning,ComputerVision,TensorFlow,PyTorch,Python,python,c,linux,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-pravaig-dynamics-bengaluru-bangalore-1-to-5-yrs-jobid-AFGBQTjUifpzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:corner stone solutions
# KeySkills: algorithms,bi,imageprocessing,python,naturallanguageprocessing,machinelearning,opencv
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-corner-stone-solutions-indore-bengaluru-bangalore-3-to-6-yrs-jobid-pYXFpbTGcpFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Maxgen Technologies
#      (More Jobs)
# KeySkills: machinelearning,internship
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-SaMaCcBOVNhzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Manish Recruiters
#      (More Jobs)
# KeySkills: MachineOperatorSheetMetalFabrication
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/python-machine-learning-engineer-manish-recruiters-ahmedabad-chennai-mumbai-chandigarh-adilabad-2-to-7-yrs-jobid-qy0WbSng__SLASH__l9zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Techno wise
#      (More Jobs)
# KeySkills: "Machinelearning","DeepLearning","GenAI","NLP","ComputerVision","python","Tensorflow","Terraform","MLOps","AzureDatabricks","MLflow","AzureMLStudio"
# Published date: Posted a month ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-techno-wise-bengaluru-bangalore-mumbai-pune-3-to-8-yrs-jobid-jsMZqViQcFVzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Maxgen Technologies
#      (More Jobs)
# KeySkills: ml,ai
# Published date: Posted a month ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-d5170EZwluJzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Maxgen Technologies
#      (More Jobs)
# KeySkills: ai
# Published date: Posted a month ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-internship-in-pune-maxgen-technologies-pune-amravati-aurangabad-sangli-satara-0-to-1-yrs-jobid-__SLASH__z01XNNKF4tzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:pattern effects labs private limited
# KeySkills: algorithms,machinelearning,Boosting
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-analyst-pattern-effects-labs-private-limited-bengaluru-bangalore-2-to-5-yrs-jobid-VAATYZp3eZdzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,python,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-lead-analytics-vidhya-bengaluru-bangalore-7-to-10-yrs-jobid-uyxvDT3Z__SLASH__L5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Vitrana
# KeySkills: algorithms,python,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-vitrana-noida-greater-noida-bengaluru-bangalore-2-to-4-yrs-jobid-Oz8RLlCNBd9zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,python,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-developer-analytics-vidhya-bengaluru-bangalore-2-to-5-yrs-jobid-TEy8QVyjtP1zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Cotocus
# KeySkills: machinelearning,artificialintelligence,docker
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/principle-engineer-in-machine-learning-cotocus-bengaluru-bangalore-8-to-11-yrs-jobid-H2AuwB5h2PpzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Cotocus
# KeySkills: machinelearning,docker,datascience
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-cotocus-bengaluru-bangalore-0-to-3-yrs-jobid-UuakCaarcmNzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Headhuntersinc consultancy Private Limited
# KeySkills: algorithms,python,java,datastructures,machinelearning
# Published date: Posted 2 days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-headhuntersinc-consultancy-private-limited-gurgaon-3-to-6-yrs-jobid-jhrKFlI__SLASH__fIZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,c,python,java,linux,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-specialist-analytics-vidhya-delhi-delhi-ncr-5-to-8-yrs-jobid-rO9iJyrD__SLASH__z1zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,python,datamining,machinelearning,mysql
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/data-scientist-machine-learning-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-RlMk9LiZYLRzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:CONNECTING 2 WORK
# KeySkills: algorithms,python,machinelearning,linux,opencv
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-expert-connecting-2-work-thiruvananthapuram-2-to-5-yrs-jobid-C1xw5rjL8n5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Triveni Engineering & Industries Ltd
# KeySkills: algorithms,python,django,datastructures,machinelearning,docker
# Published date: Posted 2 days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-triveni-engineering-industries-ltd-ahmedabad-surat-1-to-3-yrs-jobid-4hQ__SLASH__wojGtLhzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:cloudxlab
# KeySkills: python,machinelearning,sql,apache,linux,bigdata,forms
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-cloudxlab-bengaluru-bangalore-0-to-3-yrs-jobid-fT__PLUS__Nn48VrvpzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,sql,hadoop,bigdata,python,sas,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/data-scientist-machine-learning-analytics-vidhya-delhi-delhi-ncr-4-to-7-yrs-jobid-nEp4ZLzvl6VzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Boyen Haddin Consultants LLP
# KeySkills: hive,algorithms,machinelearning,sql,pig,d3.js
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/data-engineer-machine-learning-boyen-haddin-consultants-llp-mumbai-0-to-3-yrs-jobid-c__PLUS__Hiaoj__PLUS__8P5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: telematics,java,git,hadoop,python,svn,teamplayer,machinelearning
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-specialist-analytics-vidhya-pune-5-to-8-yrs-jobid-zEPRwkS8POhzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Analytics Vidhya
# KeySkills: algorithms,python,storage,machinelearning,database,infrastructure,cloudcomputing
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-indore-bengaluru-bangalore-5-to-7-yrs-jobid-7I__PLUS__bw__PLUS__wM__PLUS__hpzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:Ideapoke
# KeySkills: algorithms,artificialintelligence,rest,python,machinelearning,openstack,opencv,soap
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-ideapoke-bengaluru-bangalore-2-to-5-yrs-jobid-Yg29r8458yNzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name:aitouch llp
# KeySkills: algorithms,python,machinelearning,linux,webdevelopment,opencv
# Published date: Posted few days ago
# More Information:https://www.timesjobs.com/job-detail/machine-learning-engineer-aitouch-llp-gurgaon-5-to-8-yrs-jobid-X1x78BrYOhdzpSvf__PLUS__uAgZw==&source=srp
